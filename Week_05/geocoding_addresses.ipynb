# %% [markdown]
# # Geocoding apartment addresses using the geoadmin API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import urllib
import fnmatch
import folium
import pandas as pd
from IPython.display import clear_output

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Get current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_05

# %% [markdown]
# ## Geocoding a single address

# %% [markdown]
# ### Define base url for address search

# %%
# Define base url for address search
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Set up search parameters: address, origins and type
parameters = {"searchText": "Theaterstrasse 17, 8400 Winterthur",
              "origins": "address",
              "type": "locations",
             }

# Urllib.parse.urlencode turns parameters into url
print(f"{base_url}{urllib.parse.urlencode(parameters)}")
# Out:
# https://api3.geo.admin.ch/rest/services/api/SearchServer?searchText=Theaterstrasse+17%2C+8400+Winterthur&origins=address&type=locations

# %% [markdown]
# ### Server request & response

# %%
# Server request
r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

# Get data in json-format
data = json.loads(r.content)
data

# Take only the first server response, convert to data frame with relevant infos
df = pd.DataFrame.from_dict(list(data.values())[0][0], orient='columns')
df.iloc[[1,4,5,6,11,12],:1]
# Out:
#                                               attrs
# featureId                                 2323240_0
# label      Theaterstrasse 17 <b>8400 Winterthur</b>
# lat                                       47.503517
# lon                                        8.727852
# x                                        262216.125
# y                                       697128.5625

# %% [markdown]
# ## Geocoding multiple addresses

# %% [markdown]
# ### Importing apartment data

# %%
# Get current working directory
print(os.getcwd())

# Show all files in the directory
flist = fnmatch.filter(os.listdir('.'), '*.csv')
for i in flist:
    print(i)

# Read the data to a pandas data frame
df = pd.read_csv('apartments_data_prepared.csv', 
                 sep=',', 
                 encoding='utf-8')[['web-scraper-order', 
                                    'address_raw', 
                                    'datetime',
                                    'rooms', 
                                    'area', 
                                    'luxurious',
                                    'price_per_m2']][:100] # first 100 apartment adresses

# Get number of rows and columns
print(df.shape)

# Show first records
df.head(10)
# Out:
# /workspaces/data_analytics/Week_05
# apartments_data_prepared.csv
# supermarkets_data_prepared.csv
# (100, 7)
#   web-scraper-order                             address_raw  \
# 0      1693998201-1       Neuhusstrasse 6, 8630 Rüti ZH, ZH
# 1      1693998201-2      Zürcherstrasse 1, 8173 Neerach, ZH
# 2      1693998201-4     Cramerstrasse 8-12, 8004 Zürich, ZH
# 3      1693998201-5       Rotachstrasse 33, 8003 Zürich, ZH
# 4     1693998201-16         Wolframplatz 1, 8045 Zürich, ZH
# 5     1693998205-25    Badenerstrasse 67, 8953 Dietikon, ZH
# 6     1693998205-26   Frowiesstrasse 36, 8344 Bäretswil, ZH
# 7     1693998205-27  Kanzleistrasse 15, 8418 Schlatt ZH, ZH
# 8     1693998205-29           Bolletweg 14, 8934 Knonau, ZH
# 9     1693998205-30            Im Zauner 24, 8352 Elsau, ZH
#
#               datetime  rooms   area  luxurious  price_per_m2
# 0  2023-09-06 15:10:34    3.0   49.0          0         29.41
# 1  2023-09-06 15:10:34    3.5   65.0          0         28.46
# 2  2023-09-06 15:10:34    2.0   54.0          0         89.87
# 3  2023-09-06 15:10:34    2.0   49.0          0         88.47
# 4  2023-09-06 15:10:34    2.0   32.0          0        109.84
# 5  2023-09-06 15:10:34    3.5  105.0          0         30.48
# 6  2023-09-06 15:10:34    5.5  140.0          0         19.64
# 7  2023-09-06 15:10:34    4.5  104.0          0         25.96
# 8  2023-09-06 15:10:34    5.5  150.0          0         22.60
# 9  2023-09-06 15:10:34    3.0   70.0          0         35.00

# %% [markdown]
# ### Geocoding multiple apartment addresses using the geoadmin API

# %%
# Define base url
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Geocode list of adresses
geolocation = []
n = 1
for i in df['address_raw'].astype(str):
    
    print('Geocoding address', 
          n, 
          'out of', 
          len(df['address_raw']), 
          ':', 
          i)
    n=n+1
    clear_output(wait=True)
    
    try:
        # Set up search parameters - address, origins and type
        parameters = {"searchText": i,
                      "origins": "address",
                      "type": "locations",
                     }

        # Server request
        r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

        # Get data
        data = json.loads(r.content)

        # Take first server response, convert to df with relevant infos
        df_loc = pd.DataFrame.from_dict(list(data.values())[0][0], 
                                        orient='columns')
        geolocation.append(df_loc.iloc[[5,6],0].astype(float))
    
    except:
        geolocation.append(pd.Series(data={'lat': None, 'lon': None}))
        

# Write lat and lon to df
df_loc = pd.DataFrame(geolocation, 
                      columns=("lat", "lon"), 
                      index=range(len(df['address_raw'])))
df['lat'] = df_loc['lat']
df['lon'] = df_loc['lon']
df.head(5)
# Out:
#   web-scraper-order                          address_raw             datetime  \
# 0      1693998201-1    Neuhusstrasse 6, 8630 Rüti ZH, ZH  2023-09-06 15:10:34
# 1      1693998201-2   Zürcherstrasse 1, 8173 Neerach, ZH  2023-09-06 15:10:34
# 2      1693998201-4  Cramerstrasse 8-12, 8004 Zürich, ZH  2023-09-06 15:10:34
# 3      1693998201-5    Rotachstrasse 33, 8003 Zürich, ZH  2023-09-06 15:10:34
# 4     1693998201-16      Wolframplatz 1, 8045 Zürich, ZH  2023-09-06 15:10:34
#
#    rooms  area  luxurious  price_per_m2        lat       lon
# 0    3.0  49.0          0         29.41  47.252171  8.845797
# 1    3.5  65.0          0         28.46  47.513332  8.474851
# 2    2.0  54.0          0         89.87        NaN       NaN
# 3    2.0  49.0          0         88.47  47.370792  8.514748
# 4    2.0  32.0          0        109.84  47.362282  8.522193

# %% [markdown]
# ### Plot addresses on map

# %%
# Initialisierung der Map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
df_sub = df.dropna()
for i in range(0, len(df_sub)):
    folium.Marker(location=(df_sub.iloc[i]['lat'], 
                            df_sub.iloc[i]['lon']), 
                  popup=df_sub.iloc[i]['address_raw']).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab3d071cc2fcbde281601232987b4e45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab3d071cc2fcbde281601232987b4e45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab3d071cc2fcbde281601232987b4e45 = L.map(
#                 &quot;map_ab3d071cc2fcbde281601232987b4e45&quot;,
#                 {
#                     center: [47.44, 8.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68983dd6d54d2387efb57a9f1b0c9a4f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ab3d071cc2fcbde281601232987b4e45);
#
#
#             var marker_53573caf2df02210df8ba26eccc4f783 = L.marker(
#                 [47.25217056274414, 8.845796585083008],
#                 {}
#             ).addTo(map_ab3d071cc2fcbde281601232987b4e45);
#
#
#         var popup_1d1face8b55f4543c1f0229843428188 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43ac48d26858ec80613c6716cb19f899 = $(`&lt;div id=&quot;html_43ac48d26858ec80613c6716cb19f899&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Neuhusstrasse 6, 8630 Rüti ZH, ZH&lt;/div&gt;`)[0];
#                 popup_1d1face8b55f4543c1f0229843428188.setContent(html_43ac48d26858ec80613c6716cb19f899);
#
#
#
#         marker_53573caf2df02210df8ba26eccc4f783.bindPopup(popup_1d1face8b55f4543c1f0229843428188)
#         ;
#
#
#
#
#             var marker_6c238277a568f28a78498ab583bfc5dc = L.marker(
#                 [47.51333236694336, 8.47485065460205],
#                 {}
#             ).addTo(map_ab3d071cc2fcbde281601232987b4e45);
#
#
#         var popup_898cb37c0212f0fe7a1f077e79c302c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e755032c752e5ff373df0b2e2547f82 = $(`&lt;div id=&quot;html_6e755032c752e5ff373df0b2e2547f82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zürcherstrasse 1, 8173 Neerach, ZH&lt;/div&gt;`)[0];
#                 popup_898cb37c0212f0fe7a1f077e79c302c3.setContent(html_6e755032c752e5ff373df0b2e2547f82);
#
#
#
#         marker_6c238277a568f28a78498ab583bfc5dc.bindPopup(popup_898cb37c0212f0fe7a1f077e79c302c3)
#         ;
#
#
#
#
#             var marker_d18f687f591c4b13778504f7f97f2f7f = L.marker(
#                 [47.370792388916016, 8.514747619628906],
#                 {}
#             ).addTo(map_ab3d071cc2fcbde281601232987b4e45);
#
#
#         var popup_6a64ec000ca0f9b34411270bf660e594 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c1eb37c6b46843708413d039f41a100 = $(`&lt;div id=&quot;html_2c1eb37c6b46843708413d039f41a100&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rotachstrasse 33, 8003 Zürich, ZH&lt;/div&gt;`)[0];
#                 popup_6a64ec000ca0f9b34411270bf660e594.setContent(html_2c1eb37c6b46843708413d039f41a100);
#
#
#
#         marker_d18f687f591c4b13778504f7f97f2f7f.bindPopup(popup_6a64ec000ca0f9b34411270bf660e594)
#         ;
#
#
#
#
#             var marker_a16cc4cee25b166fe9e6729e05440432 = L.marker(
#                 [47.362281799316406, 8.52219295501709],
#                 {}
#             ).addTo(map_ab3d071cc2fcbde281601232987b4e45);
#
#
#         var popup_f4af9459f56ff51735829d45238f7624 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6993df141bc6b7ca20228310024a6711 = $(`&lt;div id=&quot;html_6993df141bc6b7ca20228310024a6711&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wolframplatz 1, 8045 Zürich, ZH&lt;/div&gt;`)[0];
#                 popup_f4af9459f56ff51735829d45238f7624.setContent(html_6993df141bc6b7ca20228310024a6711);
#
#
#
#         marker_a16cc4cee25b166fe9e6729e05440432.bindPopup(popup_f4af9459f56ff51735829d45238f7624)
#         ;
#
#
#
#
#             var marker_fc9bc0b768df44afbdfecaa0e49a8c66 = L.marker(
#                 [47.40792465209961, 8.392560958862305],
#                 {}
#             ).addTo(map_ab3d071cc2fcbde281601232987b4e45);
#
#
#         var popup_1032b8961d44eeb9c331138f7895b26d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a109f7f8c24bddc0c03768c10356acd8 = $(`&lt;div id=&quot;html_a109f7f8c24bddc0c03768c10356acd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Badenerstrasse 67, 8953 Dietikon, ZH&lt;/div&gt;`)[0];
#                 popup_1032b8961d44eeb9c331138f7895b26d.setContent(html_a109f7f8c24bddc0c03768c10356acd8);
#
#
#
#         marker_fc9bc0b768df44afbdfecaa0e49a8c66.bindPopup(popup_1032b8961d44eeb

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('Geodata/apartments_data_geocoded.csv', 
           sep=",", 
           encoding='utf-8',
           index=False)

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.2.0-1015-azure
# Datetime: 2023-10-29 12:57:04
# Python Version: 3.10.13
# -----------------------------------
